# %%
import pandas as pd

# %%
df=pd.read_excel(r'D:\Nagesh\DataScience\ClassNotes\3rd\convert raw data - clean data.xlsx',sheet_name="Sheet2")
df
# Out:
#                                           ADDR         DT NAME     time
# 0  45 rd, kenith street, btm, bangalore 500038 2022-04-03  abc  8:30:21
# 1            45 rd,  street, hitech, Hd 500038 2022-04-02  dec  5:30:21

# %%
new=df["ADDR"].str.split(",",3,expand=True)
new
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13664\569612164.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   new=df["ADDR"].str.split(",",3,expand=True)
#        0               1        2                  3
# 0  45 rd   kenith street      btm   bangalore 500038
# 1  45 rd          street   hitech          Hd 500038

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ADDR    2 non-null      object
#  1   DT      2 non-null      datetime64[ns]
#  2   NAME    2 non-null      object
#  3   time    2 non-null      object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 192.0+ bytes

# %%
df["HouseNo"]=new[0]
df["StreetNumber"]=new[1]
df["City"]=new[2]
new1=new[3].str.split(" ",2,expand=True)
df["State"]=new1[1]
df['ZipCode']=new1[2]
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13664\2764882271.py:4: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   new1=new[3].str.split(" ",2,expand=True)
#                                           ADDR         DT NAME     time  \
# 0  45 rd, kenith street, btm, bangalore 500038 2022-04-03  abc  8:30:21
# 1            45 rd,  street, hitech, Hd 500038 2022-04-02  dec  5:30:21
#
#   HouseNo    StreetNumber     City      State ZipCode
# 0   45 rd   kenith street      btm  bangalore  500038
# 1   45 rd          street   hitech         Hd  500038

# %%
df["Day"]=df["DT"].dt.day
df["Month"]=df["DT"].dt.month
df["Year"]=df["DT"].dt.year
df
# Out:
#                                           ADDR         DT NAME     time  \
# 0  45 rd, kenith street, btm, bangalore 500038 2022-04-03  abc  8:30:21
# 1            45 rd,  street, hitech, Hd 500038 2022-04-02  dec  5:30:21
#
#   HouseNo    StreetNumber     City      State ZipCode  Day  Month  Year
# 0   45 rd   kenith street      btm  bangalore  500038    3      4  2022
# 1   45 rd          street   hitech         Hd  500038    2      4  2022

# %%
new1=df["time"].str.split(":",3,expand=True)
new1
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13664\2231658677.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   new1=df["time"].str.split(":",3,expand=True)
#    0   1   2
# 0  8  30  21
# 1  5  30  21

# %%
df["Hours"]=new1[0]
df["Minutes"]=new1[1]
df["Seconds"]=new1[2]
df
# Out:
#                                           ADDR         DT NAME     time  \
# 0  45 rd, kenith street, btm, bangalore 500038 2022-04-03  abc  8:30:21
# 1            45 rd,  street, hitech, Hd 500038 2022-04-02  dec  5:30:21
#
#   HouseNo    StreetNumber     City      State ZipCode  Day  Month  Year Hours  \
# 0   45 rd   kenith street      btm  bangalore  500038    3      4  2022     8
# 1   45 rd          street   hitech         Hd  500038    2      4  2022     5
#
#   Minutes Seconds
# 0      30      21
# 1      30      21

# %%
df.drop(df.columns[[0, 1,3]], axis=1, inplace=True)
df
# Out:
#   NAME HouseNo    StreetNumber     City      State ZipCode  Day  Month  Year  \
# 0  abc   45 rd   kenith street      btm  bangalore  500038    3      4  2022
# 1  dec   45 rd          street   hitech         Hd  500038    2      4  2022
#
#   Hours Minutes Seconds
# 0     8      30      21
# 1     5      30      21

# %%
dfMovies=pd.read_csv(r'D:\Nagesh\DataScience\ClassNotes\6th\movie.csv')
dfMovies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
dfMovies['title']
# Out:
# 0                          Toy Story (1995)
# 1                            Jumanji (1995)
# 2                   Grumpier Old Men (1995)
# 3                  Waiting to Exhale (1995)
# 4        Father of the Bride Part II (1995)
#                         ...
# 27273          Kein Bund für's Leben (2007)
# 27274         Feuer, Eis & Dosenbier (2002)
# 27275                    The Pirates (2014)
# 27276                   Rentun Ruusu (2001)
# 27277                      Innocence (2014)
# Name: title, Length: 27278, dtype: object

# %%
new=dfMovies['title'].str.replace('(','').str.replace(')','').str.split(":",2,expand=True)
new
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13664\3118932618.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   new=dfMovies['title'].str.replace('(','').str.replace(')','').str.split(":",2,expand=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_13664\3118932618.py:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   new=dfMovies['title'].str.replace('(','').str.replace(')','').str.split(":",2,expand=True)
#                                       0     1     2
# 0                        Toy Story 1995  None  None
# 1                          Jumanji 1995  None  None
# 2                 Grumpier Old Men 1995  None  None
# 3                Waiting to Exhale 1995  None  None
# 4      Father of the Bride Part II 1995  None  None
# ...

# %%
new1=new[0].str.split(' ').str[-1]
new1
# Out:
# 0        1995
# 1        1995
# 2        1995
# 3        1995
# 4        1995
#          ...
# 27273    2007
# 27274    2002
# 27275    2014
# 27276    2001
# 27277    2014
# Name: 0, Length: 27278, dtype: object

# %%
new[0].str.replace(new1[0],'').head(60)
# Out:
# 0                                            Toy Story
# 1                                              Jumanji
# 2                                     Grumpier Old Men
# 3                                    Waiting to Exhale
# 4                          Father of the Bride Part II
# 5                                                 Heat
# 6                                              Sabrina
# 7                                         Tom and Huck
# 8                                         Sudden Death
# 9                                            GoldenEye
# 10                             American President, The
# 11                                              Dracula
# 12                                               Balto
# 13                                               Nixon
# 14                                    Cutthroat Island
# 15                                              Casino
# 16                               Sense and Sensibility
# ...
